# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
tf.compat.v1.disable_eager_execution()
import seaborn as sns

# %%
df = pd.read_csv('diamonds 2.csv').loc[:, ["carat","price"]]
sns.regplot(x="carat",y="price",data = df)
plt.ylim(0,)
y_data = []
x_data = []
for x in df['carat']:
    x_data.append(x)
for y in df['price']:
    y_data.append(y)
print(np.corrcoef(x_data,y_data)[0,1])
# Out:
# 0.9215913011934779

# %%
df = pd.read_csv('diamonds 2.csv').loc[:, ["depth","price"]]
sns.regplot(x="depth",y="price",data = df)
plt.ylim(0,)
y_data = []
x_data = []
for x in df['depth']:
    x_data.append(x)
for y in df['price']:
    y_data.append(y)
print(np.corrcoef(x_data,y_data)[0,1])
# Out:
# -0.01064740458414298

# %%
df = pd.read_csv('diamonds 2.csv').loc[:, ["table","price"]]
sns.regplot(x="table",y="price",data = df)
plt.ylim(0,)
y_data = []
x_data = []
for x in df['table']:
    x_data.append(x)
for y in df['price']:
    y_data.append(y)
print(np.corrcoef(x_data,y_data)[0,1])
# Out:
# 0.127133902121742

# %%
df = pd.read_csv('diamonds 2.csv').loc[:, ["cut","price"]]
y_data = []
x_data = []
for x in df['cut']:
    x_data.append(x)
for y in df['price']:
    y_data.append(y)
plt.scatter(x_data,y_data)
plt.show()

# %%
#构建一个线性模型
d = tf.Variable(np.random.rand(1))
k = tf.Variable(np.random.rand(1))
y = k*y_data+d
#二次代价函数
loss = tf.losses.mean_squared_error(y_data,y)
#定义一个梯度下降优化器
optimizer = tf.compat.v1.train.GradientDescentOptimizer(0.3)
#最小化代价函数
train = optimizer.minimize(loss)

#初始化变量
init = tf.compat.v1.global_variables_initializer()

with tf.compat.v1.Session() as sess:
    sess.run(init)
    for i in range(41):
        sess.run(train)
        if  i%10 ==0:
            print(i,sess.run([k,d]))
    y_pred = sess.run(y)
    plt.scatter(x_data,y_data)
    plt.plot(x_data,y_pred,'r-',lw=3)
    plt.show()
# Out:
# 0 [array([18721834.08640474]), array([2346.37493468])]
# 10 [array([1.04882103e+80]), array([1.31437465e+76])]
# 20 [array([5.87562951e+152]), array([7.36329484e+148])]
# 30 [array([3.29160278e+225]), array([4.12501192e+221])]
# 40 [array([1.84399797e+298]), array([2.31088442e+294])]

# %%
df = pd.read_csv('diamonds 2.csv').loc[:, ["color","price"]]
y_data = []
x_data = []
for x in df['color']:
    x_data.append(x)
for y in df['price']:
    y_data.append(y)
plt.scatter(x_data,y_data)
plt.show()

# %%
#构建一个线性模型
d = tf.Variable(np.random.rand(1))
k = tf.Variable(np.random.rand(1))
y = k*y_data+d
#二次代价函数
loss = tf.losses.mean_squared_error(y_data,y)
#定义一个梯度下降优化器
optimizer = tf.compat.v1.train.GradientDescentOptimizer(0.3)
#最小化代价函数
train = optimizer.minimize(loss)

#初始化变量
init = tf.compat.v1.global_variables_initializer()

with tf.compat.v1.Session() as sess:
    sess.run(init)
    for i in range(41):
        sess.run(train)
        if  i%20 ==0:
            print(i,sess.run([k,d]))
    y_pred = sess.run(y)
    plt.scatter(x_data,y_data)
    plt.plot(x_data,y_pred,'r-',lw=3)
    plt.show()
# Out:
# 0 [array([13610840.78875033]), array([1706.35874714])]
# 20 [array([4.27160372e+152]), array([5.35314175e+148])]
# 40 [array([1.34059313e+298]), array([1.68002126e+294])]

# %%
df = pd.read_csv('diamonds 2.csv').loc[:, ["clarity","price"]]
y_data = []
x_data = []
for x in df['clarity']:
    x_data.append(x)
for y in df['price']:
    y_data.append(y)
plt.scatter(x_data,y_data)
plt.show()

# %%
#构建一个线性模型
d = tf.Variable(np.random.rand(1))
k = tf.Variable(np.random.rand(1))
y = k*y_data+d
#二次代价函数
loss = tf.losses.mean_squared_error(y_data,y)
#定义一个梯度下降优化器
optimizer = tf.compat.v1.train.GradientDescentOptimizer(0.3)
#最小化代价函数
train = optimizer.minimize(loss)

#初始化变量
init = tf.compat.v1.global_variables_initializer()

with tf.compat.v1.Session() as sess:
    sess.run(init)
    for i in range(41):
        sess.run(train)
        if  i%20 ==0:
            print(i,sess.run([k,d]))
    y_pred = sess.run(y)
    plt.scatter(x_data,y_data)
    plt.plot(x_data,y_pred,'r-',lw=3)
    plt.show()
# Out:
# 0 [array([3605798.74860452]), array([452.08044959])]
# 20 [array([1.13163768e+152]), array([1.41815985e+148])]
# 40 [array([3.55151319e+297]), array([4.4507297e+293])]
