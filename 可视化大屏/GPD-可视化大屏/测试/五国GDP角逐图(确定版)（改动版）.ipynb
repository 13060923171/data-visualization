# %%
from pyecharts import options as opts
from pyecharts.charts import Bar,Timeline
from pyecharts.faker import Faker
import random

attr = Faker.choose()
t1  = Timeline()
rb=[]
rb=[4.89,
4.3,
4.12,
4.45,
4.82,
4.76,
4.53,
4.52,
5.04,
5.23,
5.7,
6.16,
6.2,
5.16,
4.85,
4.39,
4.92,
4.87,
4.95,
5.08
]
fg=[ 1.36,
1.38,
1.49,
1.84,
2.12,
2.2,
2.32,
2.66,
2.92,
2.69,
2.64,
2.86,
2.68,
2.81,
2.85,
2.44,
2.47,
2.6,
2.79,
2.72
]
mg=[
    10.25,
10.58,
10.94,
11.46,
12.21,
13.04,
13.81,
14.45,
14.71,
14.45,
14.99,
15.54,
16.2,
16.78,
17.53,
18.22,
18.71,
19.52,
20.58,
21.43
]
yg=[
    1.66,
1.64,
1.78,
2.05,
2.42,
2.54,
2.71,
3.1,
2.92,
2.41,
2.48,
2.66,
2.7,
2.79,
3.06,
2.93,
2.69,
2.67,
2.86,
2.83

]
zg=[
    1.21,
1.34,
1.47,
1.66,
1.96,
2.29,
2.75,
3.55,
4.59,
5.1,
6.09,
7.55,
8.53,
9.57,
10.48,
11.06,
11.23,
12.31,
13.89,
14.34

]
for i in range(2000,2020):
    attr1 = random.shuffle(list(attr))
    bar = (
    Bar()
    .add_xaxis(["日本","法国","英国","美国","中国"])
    .add_yaxis('GDP（万亿美元）',[rb[i-2000],fg[i-2000],yg[i-2000],mg[i-2000],zg[i-2000]],label_opts = opts.LabelOpts(position = 'right'),)
    .set_series_opts(label_opts = opts.LabelOpts(is_show = True,position = 'right'))
    .reversal_axis()
    .set_global_opts(title_opts = opts.TitleOpts("{}".format(i),
                                                 pos_left = '50%',

                                                ),
                    legend_opts = opts.LegendOpts(pos_right = '10%'))

    )

    t1.add(bar,'{}年'.format(i))
t1.add_schema(
symbol = 'arrow',# 设置标记时间；
    #orient = 'vertical',
     symbol_size = 2,# 标记大小;
    play_interval = 900,# 播放时间间隔；
    control_position = 'right',# 控制位置;
linestyle_opts = opts.LineStyleOpts(width = 5,
                                   type_ = 'dashed',
                                   color = 'rgb(255,0,0,0.5)'),
    label_opts = opts.LabelOpts(color = 'rgb(0,0,255,0.5)',
                                    font_size = 15,
                                    font_style = 'italic',
                                    font_weight = 'bold',
                                     font_family ='Time New Roman',

                                position = 'left',
                                interval = 20,
                                    )
)

# %%
t1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1e37b1a351984408a0902e568c664706" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1e37b1a351984408a0902e568c664706 = echarts.init(
#                     document.getElementById('1e37b1a351984408a0902e568c664706'), 'white', {renderer: 'canvas'});
#                 var option_1e37b1a351984408a0902e568c664706 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "GDP\uff08\u4e07\u4ebf\u7f8e\u5143\uff09",
#                 "legendHoverLink": true,
#                 "data": [
#                     5.08,
#                     2.72,
#                     2.83,
#                     21.43,
#                     14.34
#                 ],
#                 "showBackground": false,
#                 "barMinHeight": 0,
#                 "barCategoryGap": "20%",
#                 "barGap": "30%",
#                 "large": false,
#                 "largeThreshold": 400,
#                 "seriesLayoutBy": "column",
#                 "datasetIndex": 0,
#                 "clip": true,
#                 "zlevel": 0,
#                 "z": 2,
#                 "label": {
#                     "show": true,
#                     "position": "right",
#                     "margin": 8
#                 },
#                 "rippleEffect": {
#                     "show": true,
#                     "brushType": "stroke",
#                     "scale": 2.5,
#                     "period": 4
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "right",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "symbol": "arrow",
#             "symbolSize": 2,
#             "playInterval": 900,
#             "bottom": "-5px",
#             "lineStyle": {
#                 "show": true,
#                 "width": 5,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "dashed",
#                 "color": "rgb(255,0,0,0.5)"
#             },
#             "label": {
#                 "show": true,
#                 "position": "left",
#                 "color": "rgb(0,0,255,0.5)",
#                 "margin": 8,
#                 "interval": 20,
#                 "fontSize": 15,
#                 "fontStyle": "italic",
#                 "fontWeight": "bold",
#                 "fontFamily": "Time New Roman"
#             },
#             "data": [
#                 "2000\u5e74",
#                 "2001\u5e74",
#                 "2002\u5e74",
#                 "2003\u5e74",
#                 "2004\u5e74",
#                 "2005\u5e74",
#                 "2006\u5e74",
#                 "2007\u5e74",
#                 "2008\u5e74",
#                 "2009\u5e74",
#                 "2010\u5e74",
#                 "2011\u5e74",
#                 "2012\u5e74",
#                 "2013\u5e74",
#                 "2014\u5e74",
#                 "2015\u5e74",
#                 "2016\u5e74",
#                 "2017\u5e74",
#                 "2018\u5e74",
#                 "2019\u5e74"
#             ]
#         },
#         "xAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 }
#             }
#         ],
#         "yAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": false,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 },
#                 "data": [
#                     "\u65e5\u672c",
#                     "\u6cd5\u56fd",
#                     "\u82f1\u56fd",
#                     "\u7f8e\u56fd",
#                     "\u4e2d\u56fd"
#                 ]
#             }
#         ]
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "GDP\uff08\u4e07\u4ebf\u7f8e\u5143\uff09"
#                     ],
#                     "selected": {
#                         "GDP\uff08\u4e07\u4ebf\u7f8e\u5143\uff09": true
#                     },
#                     "show": true,
#                     "right": "10%",
#                     "padding": 5,
#                     "itemGap": 10,
#                     "itemWidth": 25,
#                     "itemHeight": 14
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "bar",
#                     "name": "GDP\uff08\u4e07\u4ebf\u7f8e\u5143\uff09",
#                     "legendHoverLink": true,
#                     "data": [
#                         4.89,
#                         1.36,
#                         1.66,
#                         10.25,
#                         1.21
#                     ],
#                     "showBackground": false,
#                     "barMinHeight": 0,
#                     "barCategoryGap": "20%",
#                     "barGap": "30%",
#                     "large": false,
#                     "largeThreshold": 400,
#                     "seriesLayoutBy": "column",
#                     "datasetIndex": 0,
#                     "clip": true,
#                     "zlevel": 0,
#                     "z": 2,
#                     "label": {
#                         "show": true,
#                         "position": "right",
#                         "margin": 8
#                     },
#                     "rippleEffect": {
#                         "show": true,
#                         "brushType": "stroke",
#                         "scale": 2.5,
#                         "period": 4
#                     }
#                 }
#             ],
#             "xAxis": [
#                 {
#                     "show": true,
#                     "scale": false,
#                     "nameLocation": "end",
#                     "nameGap": 15,
#                     "gridIndex": 0,
#                     "inverse": false,
#                     "offset": 0,
#                     "splitNumber": 5,
#                     "minInterval": 0,
#                     "splitLine": {
#                         "show": false,
#                         "lineStyle": {
#                             "show": true,
#                             "width": 1,
#                             "opacity": 1,
#                             "curveness": 0,
#                             "type": "solid"
#                         }
#                     }
#                 }
#             ],
#             "yAxis": [
#                 {
#                     "show": true,
#                     "scale": false,
#                     "nameLocation": "end",
#                     "nameGap": 15,
#                     "gridIndex": 0,
#                     "inverse": false,
#                     "offset": 0,
#                     "splitNumber": 5,
#                     "minInterval": 0,
#                     "splitLine": {
#                         "show": false,
#                         "lineStyle
